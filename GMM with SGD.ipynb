# %% [markdown]
# # Gaussian Mixture Model via Gradient Descent
#
# In this first lab exercise, we will see how we can train a Gaussian Mixture Model (GMM) via gradient descent:
#
# - first, we will consider independant bivariate Gaussians, i.e. the correlation coefficients in the correlation matrix are null, therefore we can simply store the diagonal and model each coordinate independently - this part is already done, you just need to study the code to understand it
# - second, we will consider bivariate Gaussian with (possibly) non null correlation coefficients
#
# Your goal is to study this code, play with params and understand what is going on!

# %%
# import a lot of useful stuff

import numpy as np
import math
import sklearn.metrics
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import HTML
import scipy.stats
from sklearn.datasets import make_circles

import torch
import torch.nn as nn
import torch.optim
import math
# %matplotlib inline

# %% [markdown]
# ## 1. Simple preliminary example

# %% [markdown]
# In this section, we illustrate how we use Pytorch for optimizing the parameters of a probability distribution.

# %%
# A Pytorch module is an object that contains parameters that we are going to learn,
# in this case the parameters of an univariate Gaussian.
# It also defines a forward pass function.
class UnivariateGaussian(nn.Module):
    def __init__(self):
        super().__init__()
        
        # an univariate Gaussian is defined by a mean and a standard deviation
        self.mean = nn.Parameter(torch.zeros(1))
        # the standard deviation (std) of a Gaussian must be strictily positive.
        # Instead, we will learn the log of the std which is unconstrained.
        # then, log_std.exp() is equal to the std
        self.log_std = nn.Parameter(torch.zeros(1))
        
    # the forward function return the log of the PDF
    def forward(self, x):
        return \
            - math.log(math.sqrt(2 * math.pi)) \
            - self.log_std \
            - 0.5 * ((x - self.mean) ** 2) / (self.log_std.exp() ** 2)

# %%
# We generate training data from a Gaussian with mean 5 and std 2
gold_data = torch.FloatTensor([np.random.normal(loc=5, scale=2) for _ in range(1000)])

# we can estimate the mean and std from the data using the closed form formula

print("Closed form solution:")
print(" - mean =", gold_data.mean())
print(" - std =", gold_data.std(unbiased=False))
# Out:
# Closed form solution:
#  - mean = tensor(5.0400)
#  - std = tensor(2.0095)

# %%
# create an univariate Gaussian
unig = UnivariateGaussian()

# optimizer
optimizer = torch.optim.SGD(unig.parameters(), lr=0.01, momentum=0.9)
# We could have also used Adam
#optimizer = torch.optim.Adam(unig.parameters(), lr=0.1)

# Training loop,
# We do 1000 gradient updates here
for _ in range(1000):
    # we first need to set the gradient to 0
    # the reason is that each call to the .backward function *accumulate* gradient
    optimizer.zero_grad()
    
    # compute the log PDF each each data sample,
    # log_pdf is a vector of the size of the dataset
    log_pdf = unig(gold_data)
    #print(log_pdf.shape)
    # we sum all PDF and then normalize
    # it is usual to normalize by the number of sample
    # so that the objective don't explode.
    # i.e. the parameter estimation problem is:
    # min_theta -\sum_x (1/|D|) * log p(x)
    loss = -torch.sum(log_pdf) / len(gold_data)

    loss.backward() # compute the gradient
    optimizer.step() # update the parameters
    
print("Learned model:")
print(" - mean =", unig.mean.item())
print(" - std =", unig.log_std.exp().item())
# Out:
# Learned model:
#  - mean = 5.040016174316406
#  - std = 2.0094797611236572

# %% [markdown]
# In the following we solve the same problem but using stochastic gradient descent, i.e. at each update we use only a batch of data.

# %%
unig = UnivariateGaussian()
optimizer = torch.optim.SGD(unig.parameters(), lr=0.01, momentum=0.9)

# Here, 100 is not the number of updates
# but the number of time we will loop over the data
for _ in range(100):
    # we permute the dataset so at each
    # iteration we will look at the data
    # in a different order
    gold_data[:] = gold_data[torch.randperm(len(gold_data))]
    
    # batch of size 10
    for i in range(0, len(gold_data), 10):
        batch = gold_data[i : i+10]
        optimizer.zero_grad()

        log_pdf = unig(batch)
        # here we norm by the size of the batch
        loss = -torch.sum(log_pdf) / len(batch)

        loss.backward() # compute the gradient
        optimizer.step() # update the parameters
    
print("Learned model:")
print(" - mean =", unig.mean.item())
print(" - std =", unig.log_std.exp().item())
# Out:
# Learned model:
#  - mean = 5.0556559562683105
#  - std = 2.080714464187622

# %% [markdown]
# ## 2. Data
#
# We now generate the data we will use. They come from 3 different bivariate Gaussians where only one of them has a non null correlation.

# %%
n_coordinates = 2

n_gold_clusters = 3
n_gold_samples = 1000

# The prior distribution on clusters is not uniform!
gold_cluster_prior = [0.2, 0.4, 0.4]

gold_x_means = np.array(np.array([ [-1, -1], [-1, 1], [1, 1] ]))
gold_x_cov = np.array([
    [
        [0.5**2, 0],
        [0, 0.2**2],
    ],
    [
        [0.3**2, 0],
        [0, 0.3**2],
    ],
    [
        [0.4**2, 0.8 * 0.4 * 0.5],
        [0.8 * 0.4 * 0.5, 0.5**2],
    ],
])

# sampling

# first we sample the cluster for each point
gold_clusters = np.random.choice(n_gold_clusters, n_gold_samples, p=gold_cluster_prior)

# then we sample the coordinates
gold_data = np.empty((n_gold_samples, n_coordinates))
for i in range(n_gold_samples):
    gold_data[i] = np.random.multivariate_normal(gold_x_means[gold_clusters[i]], gold_x_cov[gold_clusters[i]])

# %%
colors = np.array(["blue", "green", "red"])

fig, ax = plt.subplots()
ax.set_xlim((-2, 2))
ax.set_ylim((-2, 2))

ax.scatter(gold_data[:,0], gold_data[:,1], color=colors[gold_clusters])

# %%
gold_data[0]
# Out:
# array([1.28219615, 0.88145059])

# %% [markdown]
# ## 1.3. Independent bivariate Gaussians
#
# **IMPORTANT** You need to exactly understand what is going on in the forward function!

# %%
class GaussianMixture(nn.Module):
    def __init__(self, n_clusters, n_coordinates):
        super().__init__()
        
        # Parameters of the prior distribution
        # we will use an exponential parameterization of the categorical distribution
        # so no constraint on this :)
        self.prior = nn.Parameter(torch.zeros(n_clusters))
        
        
        self.mean = nn.Parameter(torch.empty((1, n_clusters, n_coordinates)).normal_())
        self.log_std = nn.Parameter(torch.empty((1, n_clusters, n_coordinates)).normal_())
        
    # return log of the pdf (i.e. marginalize over the latent variable)
    def forward(self, x):
        # shape x: (n_sample, 1, n_output)
        x = x.unsqueeze(1)
        # shape: (n_sample, n_latent, n_output)
        print('x= ',x[0])
        pdf = \
            - math.log(math.sqrt(2 * math.pi)) \
            - self.log_std \
            - 0.5 * ((x - self.mean) ** 2) / (self.log_std.exp() ** 2)
        
        # reduce last dim
        pdf = pdf.sum(dim=2)
        pdf = pdf + self.prior.log_softmax(0).unsqueeze(0)
        pdf = pdf.logsumexp(dim=1)
        
        # shape of the return tensor is (n_sample,)
        return pdf

# %%
# just a function to visualize the result!
# not that there are only seven colors, so you can go only up to 7 clusters...
def visualize_independent_mixture(g):
    # sample from the learned distribution
    pred_prior = np.random.choice(g.prior.shape[0], 1000, p=g.prior.softmax(0).detach().numpy())
    pred = np.random.normal(
        loc=g.mean[0, pred_prior].detach().numpy(),
        scale=g.log_std[0, pred_prior].exp().detach().numpy()
    )

    colors = np.array([c for c in "bgrcmyk"])
    # you can do this if you want to visualize with more clusters,
    # but several clusters will have the same color...
    #colors = np.array([c for c in "bgrcmykbgrcmykbgrcmykbgrcmyk"])

    fig, ax = plt.subplots()

    ax.set_xlim((-2, 2))
    ax.set_ylim((-2, 2))

    ax.scatter(pred[:,0], pred[:,1], color=colors[pred_prior])

# %%
# Train the model with 3 latent clusters
# Note that sometimes it can completely fail (because the objective is non-convex!)
# just rerun it! :)
n_clusters = 3
g = GaussianMixture(n_clusters, n_coordinates)

optimizer = torch.optim.SGD(g.parameters(), lr=0.1, momentum=0.9)

for _ in range(1000):
    optimizer.zero_grad()
    loss = -torch.sum(g(torch.from_numpy(gold_data))) / len(gold_data)
    loss.backward()
    optimizer.step()
    
visualize_independent_mixture(g)
# Out:
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.9973,  -2.1213],
#         [ -1.4985,  -5.7927],
#         [-21.5127,  -1.7152]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.1186,  -7.2913, -23.2279], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([0., 0., 0.], requires_grad=True)
# log_solfmax=  tensor([-1.0986, -1.0986, -1.0986], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0986, -1.0986, -1.0986]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-4.2019, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.0831,  -2.0206],
#         [ -1.4907,  -4.6099],
#         [-21.7127,  -1.6693]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.9375,  -6.1007, -23.3821], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0076, -0.0105,  0.0181], requires_grad=True)
# log_solfmax=  tensor([-1.1063, -1.1092, -1.0806], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1063, -1.1092, -1.0806]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.0284, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.1928,  -1.8927],
#         [ -1.4798,  -3.5068],
#         [-22.2147,  -1.5983]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.6998,  -4.9866, -23.8131], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0167, -0.0348,  0.0515], requires_grad=True)
# log_solfmax=  tensor([-1.1160, -1.1341, -1.0478], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1160, -1.1341, -1.0478]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-2.7798, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.6511,  -1.8055],
#         [ -1.4703,  -2.7992],
#         [-23.0677,  -1.5223]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.4566,  -4.2695, -24.5900], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0214, -0.0754,  0.0968], requires_grad=True)
# log_solfmax=  tensor([-1.1226, -1.1767, -1.0044], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1226, -1.1767, -1.0044]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.4354, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.4623,  -1.7718],
#         [ -1.4633,  -2.3730],
#         [-24.2786,  -1.4507]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.2342,  -3.8363, -25.7293], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0217, -0.1288,  0.1505], requires_grad=True)
# log_solfmax=  tensor([-1.1270, -1.2341, -0.9548], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1270, -1.2341, -0.9548]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.9610, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.8275,  -1.7704],
#         [ -1.4571,  -2.1414],
#         [-25.8597,  -1.3834]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.5979,  -3.5985, -27.2432], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0217, -0.1877,  0.2094], requires_grad=True)
# log_solfmax=  tensor([-1.1337, -1.2997, -0.9026], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1337, -1.2997, -0.9026]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-4.1183, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.8353,  -1.7791],
#         [ -1.4499,  -2.0481],
#         [-27.8055,  -1.3167]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.6145,  -3.4980, -29.1222], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0236, -0.2465,  0.2701], requires_grad=True)
# log_solfmax=  tensor([-1.1447, -1.3677, -0.8510], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1447, -1.3677, -0.8510]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-4.1178, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.6861,  -1.7831],
#         [ -1.4409,  -2.0381],
#         [-29.9937,  -1.2467]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.4692,  -3.4790, -31.2404], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0268, -0.3030,  0.3298], requires_grad=True)
# log_solfmax=  tensor([-1.1591, -1.4353, -0.8025], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1591, -1.4353, -0.8025]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-4.0680, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.5235,  -1.7734],
#         [ -1.4302,  -2.0683],
#         [-32.1545,  -1.1716]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.2970,  -3.4986, -33.3261], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0290, -0.3569,  0.3859], requires_grad=True)
# log_solfmax=  tensor([-1.1740, -1.5018, -0.7590], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1740, -1.5018, -0.7590]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-4.0079, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.4103,  -1.7449],
#         [ -1.4181,  -2.1124],
#         [-33.9391,  -1.0916]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.1551,  -3.5305, -35.0307], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0279, -0.4087,  0.4366], requires_grad=True)
# log_solfmax=  tensor([-1.1862, -1.5670, -0.7217], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1862, -1.5670, -0.7217]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.9564, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3535,  -1.6948],
#         [ -1.4047,  -2.1562],
#         [-35.0755,  -1.0092]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -3.0482,  -3.5609, -36.0846], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0213, -0.4592,  0.4804], requires_grad=True)
# log_solfmax=  tensor([-1.1930, -1.6309, -0.6913], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1930, -1.6309, -0.6913]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.9144, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3366,  -1.6222],
#         [ -1.3903,  -2.1930],
#         [-35.5196,  -0.9280]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.9588,  -3.5833, -36.4476], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.0078, -0.5086,  0.5164], requires_grad=True)
# log_solfmax=  tensor([-1.1924, -1.6933, -0.6682], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1924, -1.6933, -0.6682]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.8702, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3398,  -1.5277],
#         [ -1.3749,  -2.2203],
#         [-35.4749,  -0.8525]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.8674,  -3.5952, -36.3275], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.0134, -0.5574,  0.5439], requires_grad=True)
# log_solfmax=  tensor([-1.1832, -1.7540, -0.6527], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1832, -1.7540, -0.6527]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.8093, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3474,  -1.4122],
#         [ -1.3589,  -2.2374],
#         [-35.2595,  -0.7870]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.7596,  -3.5963, -36.0465], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.0431, -0.6057,  0.5626], requires_grad=True)
# log_solfmax=  tensor([-1.1644, -1.8131, -0.6448], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1644, -1.8131, -0.6448]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.7199, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3493,  -1.2781],
#         [ -1.3427,  -2.2449],
#         [-35.1351,  -0.7343]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.6275,  -3.5876, -35.8694], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.0815, -0.6538,  0.5723], requires_grad=True)
# log_solfmax=  tensor([-1.1356, -1.8709, -0.6448], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1356, -1.8709, -0.6448]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.5946, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3399,  -1.1288],
#         [ -1.3270,  -2.2439],
#         [-35.2135,  -0.6965]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.4686,  -3.5708, -35.9101], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.1288, -0.7021,  0.5733], requires_grad=True)
# log_solfmax=  tensor([-1.0970, -1.9280, -0.6526], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0970, -1.9280, -0.6526]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.4305, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.3163,  -0.9693],
#         [ -1.3125,  -2.2356],
#         [-35.4565,  -0.6760]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.2856,  -3.5481, -36.1325], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.1845, -0.7509,  0.5664], requires_grad=True)
# log_solfmax=  tensor([-1.0500, -1.9853, -0.6680], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0500, -1.9853, -0.6680]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.2303, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.2779,  -0.8062],
#         [ -1.3002,  -2.2214],
#         [-35.7242,  -0.6768]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -2.0840,  -3.5216, -36.4010], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.2469, -0.8001,  0.5532], requires_grad=True)
# log_solfmax=  tensor([-0.9967, -2.0437, -0.6904], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9967, -2.0437, -0.6904]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-3.0007, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.2251,  -0.6452],
#         [ -1.2911,  -2.2023],
#         [-35.8249,  -0.7039]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.8703,  -3.4934, -36.5289], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.3137, -0.8498,  0.5361], requires_grad=True)
# log_solfmax=  tensor([-0.9406, -2.1041, -0.7182], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9406, -2.1041, -0.7182]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-2.7511, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.1593,  -0.4899],
#         [ -1.2861,  -2.1791],
#         [-35.5386,  -0.7597]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.6492,  -3.4652, -36.2983], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.3819, -0.8996,  0.5177], requires_grad=True)
# log_solfmax=  tensor([-0.8850, -2.1665, -0.7493], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8850, -2.1665, -0.7493]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-2.4900, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -1.0826,  -0.3456],
#         [ -1.2855,  -2.1526],
#         [-34.6743,  -0.8389]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.4281,  -3.4381, -35.5132], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4490, -0.9492,  0.5002], requires_grad=True)
# log_solfmax=  tensor([-0.8328, -2.2309, -0.7815], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8328, -2.2309, -0.7815]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-2.2283, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.9997,  -0.2261],
#         [ -1.2889,  -2.1235],
#         [-33.1945,  -0.9303]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.2258,  -3.4124, -34.1248], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5129, -0.9985,  0.4856], requires_grad=True)
# log_solfmax=  tensor([-0.7856, -2.2969, -0.8129], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.7856, -2.2969, -0.8129]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.9869, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.9170,  -0.1494],
#         [ -1.2952,  -2.0926],
#         [-31.2330,  -1.0218]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -1.0664,  -3.3878, -32.2548], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5718, -1.0471,  0.4753], requires_grad=True)
# log_solfmax=  tensor([-0.7448, -2.3638, -0.8414], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.7448, -2.3638, -0.8414]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.7920, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.8393,  -0.1112],
#         [ -1.3035,  -2.0600],
#         [-28.9959,  -1.1044]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.9505,  -3.3635, -30.1003], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6237, -1.0947,  0.4711], requires_grad=True)
# log_solfmax=  tensor([-0.7119, -2.4303, -0.8645], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.7119, -2.4303, -0.8645]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.6465, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.7679,  -0.0681],
#         [ -1.3129,  -2.0259],
#         [-26.6865,  -1.1727]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.8360,  -3.3388, -27.8592], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6661, -1.1406,  0.4746], requires_grad=True)
# log_solfmax=  tensor([-0.6881, -2.4948, -0.8796], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.6881, -2.4948, -0.8796]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.5107, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[-6.9897e-01,  1.9553e-02],
#         [-1.3225e+00, -1.9902e+00],
#         [-2.4474e+01, -1.2245e+00]], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.6794,  -3.3126, -25.6987], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6971, -1.1841,  0.4871], requires_grad=True)
# log_solfmax=  tensor([-0.6745, -2.5556, -0.8845], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.6745, -2.5556, -0.8845]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3430, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.6248,   0.1271],
#         [ -1.3312,  -1.9532],
#         [-22.4797,  -1.2599]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.4977,  -3.2844, -23.7396], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7156, -1.2249,  0.5093], requires_grad=True)
# log_solfmax=  tensor([-0.6715, -2.6121, -0.8778], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.6715, -2.6121, -0.8778]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1605, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.5367,   0.1913],
#         [ -1.3381,  -1.9154],
#         [-20.7736,  -1.2799]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3454,  -3.2534, -22.0535], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7216, -1.2630,  0.5414], requires_grad=True)
# log_solfmax=  tensor([-0.6793, -2.6640, -0.8595], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.6793, -2.6640, -0.8595]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.0173, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.4290,   0.1859],
#         [ -1.3424,  -1.8772],
#         [-19.3878,  -1.2863]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.2431,  -3.2196, -20.6741], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7160, -1.2986,  0.5827], requires_grad=True)
# log_solfmax=  tensor([-0.6974, -2.7120, -0.8307], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.6974, -2.7120, -0.8307]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-0.9337, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.3037,   0.1324],
#         [ -1.3439,  -1.8392],
#         [-18.3329,  -1.2807]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.1713,  -3.1831, -19.6136], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7002, -1.3319,  0.6318], requires_grad=True)
# log_solfmax=  tensor([-0.7251, -2.7572, -0.7935], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.7251, -2.7572, -0.7935]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-0.8900, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1730,   0.0563],
#         [ -1.3433,  -1.8016],
#         [-17.6027,  -1.2642]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.1167,  -3.1449, -18.8670], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6767, -1.3633,  0.6867], requires_grad=True)
# log_solfmax=  tensor([-0.7608, -2.8008, -0.7508], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.7608, -2.8008, -0.7508]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-0.8713, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.0574,  -0.0325],
#         [ -1.3416,  -1.7647],
#         [-17.1682,  -1.2378]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.0899,  -3.1064, -18.4061], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6479, -1.3931,  0.7452], requires_grad=True)
# log_solfmax=  tensor([-0.8029, -2.8439, -0.7057], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8029, -2.8439, -0.7057]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-0.8865, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.0202,  -0.1291],
#         [ -1.3397,  -1.7286],
#         [-16.9760,  -1.2022]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.1088,  -3.0683, -18.1782], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6164, -1.4214,  0.8050], requires_grad=True)
# log_solfmax=  tensor([-0.8492, -2.8871, -0.6607], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8492, -2.8871, -0.6607]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-0.9513, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.0414,  -0.2246],
#         [ -1.3378,  -1.6931],
#         [-16.9627,  -1.1588]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.1832,  -3.0309, -18.1215], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5843, -1.4482,  0.8639], requires_grad=True)
# log_solfmax=  tensor([-0.8976, -2.9300, -0.6179], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8976, -2.9300, -0.6179]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.0732, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[-2.6756e-04, -3.0848e-01],
#         [-1.3361e+00, -1.6580e+00],
#         [-1.7071e+01, -1.1106e+00]], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3087,  -2.9941, -18.1816], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5533, -1.4731,  0.9198], requires_grad=True)
# log_solfmax=  tensor([-0.9457, -2.9720, -0.5791], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9457, -2.9720, -0.5791]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2455, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.0847,  -0.3727],
#         [ -1.3343,  -1.6233],
#         [-17.2585,  -1.0620]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.4574,  -2.9576, -18.3205], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5250, -1.4961,  0.9710], requires_grad=True)
# log_solfmax=  tensor([-0.9912, -3.0123, -0.5452], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9912, -3.0123, -0.5452]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.4378, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1622,  -0.4132],
#         [ -1.3322,  -1.5891],
#         [-17.4992,  -1.0180]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.5754,  -2.9213, -18.5172], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5010, -1.5170,  1.0160], requires_grad=True)
# log_solfmax=  tensor([-1.0320, -3.0500, -0.5169], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0320, -3.0500, -0.5169]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.5948, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1868,  -0.4294],
#         [ -1.3297,  -1.5555],
#         [-17.7785,  -0.9830]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.6162,  -2.8852, -18.7614], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4822, -1.5360,  1.0538], requires_grad=True)
# log_solfmax=  tensor([-1.0661, -3.0843, -0.4945], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0661, -3.0843, -0.4945]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.6686, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1559,  -0.4232],
#         [ -1.3270,  -1.5225],
#         [-18.0873,  -0.9596]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.5791,  -2.8495, -19.0469], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4694, -1.5530,  1.0836], requires_grad=True)
# log_solfmax=  tensor([-1.0921, -3.1145, -0.4779], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0921, -3.1145, -0.4779]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.6576, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1049,  -0.3982],
#         [ -1.3243,  -1.4903],
#         [-18.4175,  -0.9483]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.5032,  -2.8146, -19.3657], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4631, -1.5683,  1.1052], requires_grad=True)
# log_solfmax=  tensor([-1.1091, -3.1405, -0.4670], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1091, -3.1405, -0.4670]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.5993, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.0699,  -0.3591],
#         [ -1.3219,  -1.4589],
#         [-18.7593,  -0.9476]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.4291,  -2.7808, -19.7069], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4634, -1.5820,  1.1186], requires_grad=True)
# log_solfmax=  tensor([-1.1168, -3.1621, -0.4615], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1168, -3.1621, -0.4615]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.5336, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.0654,  -0.3109],
#         [ -1.3200,  -1.4284],
#         [-19.1012,  -0.9550]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3763,  -2.7484, -20.0562], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4700, -1.5943,  1.1243], requires_grad=True)
# log_solfmax=  tensor([-1.1154, -3.1797, -0.4611], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1154, -3.1797, -0.4611]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.4799, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.0882,  -0.2588],
#         [ -1.3186,  -1.3990],
#         [-19.4293,  -0.9675]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3470,  -2.7176, -20.3968], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.4825, -1.6055,  1.1230], requires_grad=True)
# log_solfmax=  tensor([-1.1057, -3.1937, -0.4652], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.1057, -3.1937, -0.4652]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.4411, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1287,  -0.2075],
#         [ -1.3177,  -1.3707],
#         [-19.7278,  -0.9822]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3362,  -2.6884, -20.7100], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5002, -1.6156,  1.1154], requires_grad=True)
# log_solfmax=  tensor([-1.0887, -3.2046, -0.4736], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0887, -3.2046, -0.4736]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.4135, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1771,  -0.1609],
#         [ -1.3173,  -1.3437],
#         [-19.9805,  -0.9970]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3380,  -2.6610, -20.9775], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5222, -1.6249,  1.1027], requires_grad=True)
# log_solfmax=  tensor([-1.0660, -3.2131, -0.4855], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0660, -3.2131, -0.4855]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3926, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.2250,  -0.1221],
#         [ -1.3172,  -1.3180],
#         [-20.1742,  -1.0101]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3471,  -2.6352, -21.1843], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5473, -1.6334,  1.0861], requires_grad=True)
# log_solfmax=  tensor([-1.0392, -3.2199, -0.5004], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0392, -3.2199, -0.5004]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3749, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.2659,  -0.0937],
#         [ -1.3173,  -1.2938],
#         [-20.3019,  -1.0209]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3596,  -2.6111, -21.3228], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.5744, -1.6412,  1.0668], requires_grad=True)
# log_solfmax=  tensor([-1.0099, -3.2255, -0.5175], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.0099, -3.2255, -0.5175]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3581, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.2946,  -0.0779],
#         [ -1.3176,  -1.2709],
#         [-20.3647,  -1.0291]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3724,  -2.5885, -21.3938], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6022, -1.6482,  1.0460], requires_grad=True)
# log_solfmax=  tensor([-0.9798, -3.2303, -0.5360], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9798, -3.2303, -0.5360]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3408, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.3077,  -0.0754],
#         [ -1.3180,  -1.2494],
#         [-20.3703,  -1.0350]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3831,  -2.5674, -21.4053], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6296, -1.6546,  1.0250], requires_grad=True)
# log_solfmax=  tensor([-0.9504, -3.2346, -0.5550], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9504, -3.2346, -0.5550]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3221, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.3038,  -0.0849],
#         [ -1.3186,  -1.2292],
#         [-20.3297,  -1.0392]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3887,  -2.5477, -21.3689], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6554, -1.6602,  1.0048], requires_grad=True)
# log_solfmax=  tensor([-0.9230, -3.2387, -0.5736], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9230, -3.2387, -0.5736]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.3004, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.2837,  -0.1023],
#         [ -1.3194,  -1.2101],
#         [-20.2528,  -1.0424]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3860,  -2.5295, -21.2952], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6788, -1.6653,  0.9865], requires_grad=True)
# log_solfmax=  tensor([-0.8986, -3.2427, -0.5910], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8986, -3.2427, -0.5910]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2734, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.2506,  -0.1225],
#         [ -1.3205,  -1.1921],
#         [-20.1466,  -1.0450]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3731,  -2.5126, -21.1916], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6990, -1.6697,  0.9707], requires_grad=True)
# log_solfmax=  tensor([-0.8779, -3.2466, -0.6062], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8779, -3.2466, -0.6062]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2401, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.2099,  -0.1418],
#         [ -1.3219,  -1.1751],
#         [-20.0157,  -1.0475]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3517,  -2.4970, -21.0632], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7154, -1.6736,  0.9583], requires_grad=True)
# log_solfmax=  tensor([-0.8615, -3.2504, -0.6186], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8615, -3.2504, -0.6186]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2025, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1683,  -0.1585],
#         [ -1.3237,  -1.1590],
#         [-19.8640,  -1.0497]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3268,  -2.4827, -20.9137], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7276, -1.6770,  0.9494], requires_grad=True)
# log_solfmax=  tensor([-0.8495, -3.2541, -0.6278], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8495, -3.2541, -0.6278]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1660, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1326,  -0.1730],
#         [ -1.3258,  -1.1437],
#         [-19.6969,  -1.0515]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3056,  -2.4695, -20.7484], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7356, -1.6798,  0.9442], requires_grad=True)
# log_solfmax=  tensor([-0.8422, -3.2576, -0.6335], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8422, -3.2576, -0.6335]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1376, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1086,  -0.1859],
#         [ -1.3283,  -1.1292],
#         [-19.5225,  -1.0527]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.2946,  -2.4575, -20.5752], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7394, -1.6822,  0.9429], requires_grad=True)
# log_solfmax=  tensor([-0.8392, -3.2608, -0.6357], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8392, -3.2608, -0.6357]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1236, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1001,  -0.1977],
#         [ -1.3311,  -1.1154],
#         [-19.3518,  -1.0532]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.2978,  -2.4465, -20.4050], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7392, -1.6842,  0.9450], requires_grad=True)
# log_solfmax=  tensor([-0.8403, -3.2637, -0.6346], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8403, -3.2637, -0.6346]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1278, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1075,  -0.2079],
#         [ -1.3341,  -1.1024],
#         [-19.1974,  -1.0530]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3155,  -2.4365, -20.2504], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7356, -1.6858,  0.9502], requires_grad=True)
# log_solfmax=  tensor([-0.8451, -3.2664, -0.6305], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8451, -3.2664, -0.6305]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1499, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1271,  -0.2160],
#         [ -1.3374,  -1.0901],
#         [-19.0718,  -1.0524]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3431,  -2.4275, -20.1242], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7290, -1.6870,  0.9580], requires_grad=True)
# log_solfmax=  tensor([-0.8530, -3.2689, -0.6240], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8530, -3.2689, -0.6240]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.1850, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1504,  -0.2214],
#         [ -1.3407,  -1.0786],
#         [-18.9846,  -1.0513]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3718,  -2.4193, -20.0359], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7200, -1.6878,  0.9679], requires_grad=True)
# log_solfmax=  tensor([-0.8634, -3.2713, -0.6156], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8634, -3.2713, -0.6156]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2237, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1678,  -0.2237],
#         [ -1.3440,  -1.0679],
#         [-18.9406,  -1.0499]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3915,  -2.4119, -19.9905], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.7093, -1.6884,  0.9791], requires_grad=True)
# log_solfmax=  tensor([-0.8757, -3.2735, -0.6060], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8757, -3.2735, -0.6060]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2552, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1723,  -0.2229],
#         [ -1.3472,  -1.0580],
#         [-18.9388,  -1.0481]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3952,  -2.4052, -19.9869], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6977, -1.6887,  0.9910], requires_grad=True)
# log_solfmax=  tensor([-0.8891, -3.2755, -0.5957], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.8891, -3.2755, -0.5957]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2721, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1635,  -0.2195],
#         [ -1.3504,  -1.0488],
#         [-18.9727,  -1.0457]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3829,  -2.3992, -20.0184], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6857, -1.6888,  1.0031], requires_grad=True)
# log_solfmax=  tensor([-0.9029, -3.2773, -0.5854], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9029, -3.2773, -0.5854]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2735, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1466,  -0.2140],
#         [ -1.3536,  -1.0402],
#         [-19.0322,  -1.0426]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3606,  -2.3938, -20.0747], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6738, -1.6885,  1.0147], requires_grad=True)
# log_solfmax=  tensor([-0.9165, -3.2788, -0.5756], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9165, -3.2788, -0.5756]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2648, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1293,  -0.2072],
#         [ -1.3567,  -1.0322],
#         [-19.1055,  -1.0388]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3365,  -2.3889, -20.1443], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6627, -1.6881,  1.0254], requires_grad=True)
# log_solfmax=  tensor([-0.9292, -3.2799, -0.5665], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9292, -3.2799, -0.5665]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2535, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1175,  -0.1998],
#         [ -1.3598,  -1.0248],
#         [-19.1824,  -1.0343]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3173,  -2.3846, -20.2167], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6526, -1.6873,  1.0346], requires_grad=True)
# log_solfmax=  tensor([-0.9406, -3.2805, -0.5586], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9406, -3.2805, -0.5586]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2458, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1140,  -0.1924],
#         [ -1.3631,  -1.0177],
#         [-19.2549,  -1.0296]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3064,  -2.3808, -20.2845], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6440, -1.6862,  1.0422], requires_grad=True)
# log_solfmax=  tensor([-0.9503, -3.2805, -0.5521], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9503, -3.2805, -0.5521]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2445, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1188,  -0.1852],
#         [ -1.3664,  -1.0111],
#         [-19.3186,  -1.0248]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3040,  -2.3776, -20.3434], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6369, -1.6848,  1.0479], requires_grad=True)
# log_solfmax=  tensor([-0.9579, -3.2797, -0.5470], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9579, -3.2797, -0.5470]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2496, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1299,  -0.1783],
#         [ -1.3699,  -1.0049],
#         [-19.3716,  -1.0205]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3082,  -2.3749, -20.3921], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6316, -1.6831,  1.0515], requires_grad=True)
# log_solfmax=  tensor([-0.9634, -3.2782, -0.5435], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9634, -3.2782, -0.5435]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2592, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1444,  -0.1719],
#         [ -1.3736,  -0.9991],
#         [-19.4135,  -1.0171]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3164,  -2.3727, -20.4307], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6280, -1.6812,  1.0532], requires_grad=True)
# log_solfmax=  tensor([-0.9667, -3.2759, -0.5415], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9667, -3.2759, -0.5415]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2704, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1590,  -0.1663],
#         [ -1.3774,  -0.9937],
#         [-19.4444,  -1.0150]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3253,  -2.3712, -20.4595], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6261, -1.6790,  1.0529], requires_grad=True)
# log_solfmax=  tensor([-0.9677, -3.2729, -0.5410], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9677, -3.2729, -0.5410]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2803, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1708,  -0.1618],
#         [ -1.3814,  -0.9888],
#         [-19.4642,  -1.0145]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3326,  -2.3702, -20.4787], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6258, -1.6766,  1.0508], requires_grad=True)
# log_solfmax=  tensor([-0.9668, -3.2693, -0.5419], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9668, -3.2693, -0.5419]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2864, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1774,  -0.1589],
#         [ -1.3856,  -0.9843],
#         [-19.4726,  -1.0154]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3363,  -2.3698, -20.4880], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6270, -1.6741,  1.0471], requires_grad=True)
# log_solfmax=  tensor([-0.9641, -3.2651, -0.5439], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-0.9641, -3.2651, -0.5439]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.2873, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[ -0.1778,  -0.1582],
#         [ -1.3898,  -0.9802],
#         [-19.4696,  -1.0179]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.3360,  -2.3700, -20.4875], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([ 0.6293, -1.6714,  1.0421], requires_grad=True)
# ...
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)
# x=  tensor([[1.2822, 0.8815]], dtype=torch.float64)
# pdf=  tensor([[  0.3562,  -1.0573],
#         [ -1.3312,   0.1109],
#         [-16.9459,  -1.0431]], dtype=torch.float64, grad_fn=<SelectBackward>)
# pdf=  tensor([ -0.7011,  -1.2203, -17.9890], dtype=torch.float64,
#        grad_fn=<SelectBackward>)
# torch.Size([1000, 3])
# prior=  Parameter containing:
# tensor([-0.4987, -0.1941,  0.6928], requires_grad=True)
# log_solfmax=  tensor([-1.7314, -1.4267, -0.5398], grad_fn=<LogSoftmaxBackward>)
# unsqueeze=  tensor([[-1.7314, -1.4267, -0.5398]], grad_fn=<UnsqueezeBackward0>)
# torch.Size([1, 3])
# pdf=  tensor(-1.8409, dtype=torch.float64, grad_fn=<SelectBackward>)

# %%
# On of the cluster in the dataset has a full covariance matrix,
# we cannot approximate it with a single Gaussian that has independent coordinate,
# but we can increase the number of cluster in our model to try to fit it with 
# several bivariate Gaussians!
n_clusters = 5
g = GaussianMixture(n_clusters, n_coordinates)

optimizer = torch.optim.SGD(g.parameters(), lr=0.1, momentum=0.9)

for _ in range(1000):
    optimizer.zero_grad()
    loss = -torch.sum(g(torch.from_numpy(gold_data))) / len(gold_data)
    loss.backward()
    optimizer.step()
    
visualize_independent_mixture(g)

# %% [markdown]
# ## 1.4. GMM with full covariance bivariate Gaussian
#
# We will now move to the same example, but using a model that can learn models with non null correlation between coordinates.

# %%
class GaussianMixture(nn.Module):
    # we only pass the number of clusters,
    # we have a single correlation coefficient
    # so we are restricted to 2 coordinates only
    def __init__(self, n_clusters):
        super().__init__()
        
        # Parameters of the prior distribution
        # we will use an exponential parameterization of the categorical distribution
        # so no constraint on this :)
        self.prior = nn.Parameter(torch.zeros(n_clusters))

        
        self.mean = nn.Parameter(torch.empty((1, n_clusters, 2)).normal_())
        self.log_std = nn.Parameter(torch.empty((1, n_clusters, 2)).normal_())
        
        # The correlation coefficient
        # not that we learn a reparameterization that is unconstrained,
        # and the coef is self.reparemterized_coef.tanh(),
        # so the value is between -1 and 1 as expected
        # (one limitation is that we can't have a coef=1 or =-1, but who cares?)
        self.reparameterized_coef = nn.Parameter(torch.empty((1, n_clusters)).normal_())
        
    # return log of the pdf (i.e. marginalize over the latent variable)
    # formula is avalable here: https://en.wikipedia.org/wiki/Multivariate_normal_distribution#Bivariate_case
    # remember we are interested by the log PDF!
    def forward(self, x):
        # shape x: (n_sample, 1, n_output)
        x = x.unsqueeze(1)
        p = self.reparameterized_coef.tanh()
        # shape: (n_sample, n_latent, n_output)

        pdf = \
            - torch.log(2 * math.pi * self.log_std.exp().prod(2) * torch.sqrt(1 - p*p)) \
            - (1 / (2 * (1 - p * p))) * (
                ((x - self.mean).pow(2) / (self.log_std.exp().pow(2))).sum(2)
                - 2 * p * (x - self.mean).prod(2) / self.log_std.exp().prod(2)
            )
        
        pdf = pdf + self.prior.log_softmax(0).unsqueeze(0)
        pdf = pdf.logsumexp(dim=1)
        
        # shape of the return tensor is (n_sample,)
        return pdf

# %%
# On of the cluster in the dataset has a full covariance matrix,
# we cannot approximate it with a single Gaussian that has independent coordinate,
# but we can increase the number of cluster in our model to try to fit it with 
# several bivariate Gaussians!
n_clusters = 3
g = GaussianMixture(n_clusters)

optimizer = torch.optim.SGD(g.parameters(), lr=0.01, momentum=0.9)

for _ in range(1000):
    optimizer.zero_grad()
    loss = -torch.sum(g(torch.from_numpy(gold_data))) / len(gold_data)
    loss.backward()
    optimizer.step()

# %%
# sample from the learned distribution
pred_prior = np.random.choice(g.prior.shape[0], 1000, p=g.prior.softmax(0).detach().numpy())

x_means = g.mean.squeeze(0).detach().numpy()
x_cov = np.empty((g.prior.shape[0], 2, 2))
for i in range(g.prior.shape[0]):
    std1 = g.log_std[0, i, 0].exp().item()
    std2 = g.log_std[0, i, 1].exp().item()
    p = g.reparameterized_coef[0, i].tanh().item()

    x_cov[i, 0, 0] = std1 * std1
    x_cov[i, 1, 1] = std2 * std2
    x_cov[i, 0, 1] = std1 * std2 * p
    x_cov[i, 1, 0] = std1 * std2 * p

# then we sample the coordinates
pred = np.empty((1000, 2))
for i in range(1000):
    pred[i] = np.random.multivariate_normal(x_means[pred_prior[i]], x_cov[pred_prior[i]])

colors = np.array([c for c in "bgrcmyk"])
# you can do this if you want to visualize with more clusters,
# but several clusters will have the same color...
#colors = np.array([c for c in "bgrcmykbgrcmykbgrcmykbgrcmyk"])

fig, ax = plt.subplots()

ax.set_xlim((-2, 2))
ax.set_ylim((-2, 2))

ax.scatter(pred[:,0], pred[:,1], color=colors[pred_prior])
